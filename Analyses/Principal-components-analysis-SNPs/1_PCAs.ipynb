# %% [markdown]
# # PCAs per region
# How genetic information can provide the same information than geography, phylogeny and network.
#
# Create PCAs organized in three or four plots that represent:
# 1. All species in all regions
# 2. Only species in Mexican regions (and centralamerica)
# 3. Only species in north south america
# 4. Maybe species in central america alone with jamaican species
#
#
# ### This was re-run on May 10, 2021 to be sure that we included 11 regions instead of 10

# %%
import ipyrad.analysis as ipa
import pandas as pd
import toyplot
import dbgdrive

# %%
#load snp hdf5 file
SNPS = "/home/deren/Documents/Viburnum-Oreinotinus/assembly_hic_feb/full_dataset_outfiles/full_dataset.snps.hdf5"

# %%
#Create big imap with all species and all samples per species
##import and load database
import dbgdrive
fulldata = dbgdrive.get_database(sheet_name='sample-data', id_spreadsheet='1mnbZVtnI4AQDseWaawV2au4bNyFD_B9M0z8REMXbOcs', api_key='AIzaSyCbfzhhYZg6f3nDSFF9hbHQOMWx2td611o')

#those regions correspond to the Early March 2021 version, not with late march or april
regions = dbgdrive.get_database(sheet_name='regions', id_spreadsheet='1mnbZVtnI4AQDseWaawV2au4bNyFD_B9M0z8REMXbOcs', api_key='AIzaSyCbfzhhYZg6f3nDSFF9hbHQOMWx2td611o')

# %%
##import collections to create an empty dict
from collections import defaultdict


#create empty dict
imap = defaultdict(list)

#go row by row
for index, row in fulldata.iterrows():
    #only check fulldataset specimens
    if row["full_dataset_withAyava"]:
        if row["Last_valid_name"] != "dentatum": 
            sp = row["Last_valid_name"]
            region = regions[regions["Species"] == sp]["Region"].values[0]
            imap[region].append(row["NameInAssembly"])

# %%
len(imap)
# Out:
# 11

# %%
count = 0
for i in imap:
    count += len(imap[i])
print (count)
# Out:
# 178

# %%
# require that 50% of samples have data in each group
minmap = {i: 0.5 for i in imap}

# %% [markdown]
# ## Define color dicts for coloring pca

# %%
#get colors from database
region_colors = {}
for row, region in enumerate(regions["RegionUnique"]):
    if region != None: 
        region_colors[region] = regions["ColorRegionUnique"][row]

# %% [markdown]
# ## Test with sample imputation

# %%
# testing with sample without imputation (base 100% on imap)
pcaSample = ipa.pca(
    data=SNPS,
    imap=imap,
    minmap=minmap,
    mincov=0.75,
    impute_method="sample",
)
# Out:
# Samples: 178
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 193270
# Filtered (mincov): 3357698
# Filtered (minmap): 3225437
# Filtered (subsample invariant): 957960
# Filtered (minor allele frequency): 0
# Filtered (combined): 3375216
# Sites after filtering: 32182
# Sites containing missing values: 32172 (99.97%)
# Missing values in SNP matrix: 1209181 (21.11%)
# SNPs (total): 32182
# SNPs (unlinked): 2381
# Imputation: 'sampled'; (0, 1, 2) = 94.0%, 4.0%, 2.0%

# %%
pcaSample.run()
# Out:
# Subsampling SNPs: 2381/32182

# %%
# store the PC axes as a dataframe
df = pd.DataFrame(pcaSample.pcaxes[0], index=pcaSample.names)

# write the PC axes to a CSV file
df.to_csv("analysis_pca/pcaSample_analysis.csv")

# %%
#create a list of colors following imap order
colors = [region_colors[k] for k in imap]

pcaSample.draw(colors=colors, cycle=10,
#               outfile="pcaSampleMay2021.svg"
              )
# Out:
# (<toyplot.canvas.Canvas at 0x7f34969bf050>,
#  <toyplot.coordinates.Cartesian at 0x7f34969bf590>)
# <div class="toyplot" id="tdb006e58a9d84219b2cd9641f932ba44" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t5fe8ed91c86c479496e37d1f1444b7c6" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 300.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tcf1da8b3b28b4475b0129d2e73786a0e"><clipPath id="tbe5655bc719d4f0aa971b9428c90e6d9"><rect height="220.0" width="240.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tbe5655bc719d4f0aa971b9428c90e6d9)"><g class="toyplot-mark-Point" id="t093d77d44c4a43ee8094f238f2d58dd1"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(124.65116737141408, 216.56722817027125)"><title>__EJE_617</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(129.06745118832978, 205.99623994926486)"><title>__EJE_619</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(114.68334530288321, 183.2661226241308)"><title>__EJE_629</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(122.97202691234553, 203.53800104051945)"><title>__EJE_630</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(120.41819410314841, 198.6987755517679)"><title>__EJE_631</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(99.36211566176326, 173.24712498639857)"><title>acutifolium_DRY3_MEX_006</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(99.74018157891469, 177.10955295690923)"><title>acutifolium_MEX_005</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(123.1784283510812, 198.8028666430419)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(118.97219804138176, 197.97126101374283)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(107.74390148119154, 194.47740710234785)"><title>acutifolium_MJD_60</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(103.79102112484867, 196.21873509782762)"><titl ...

# %% [markdown]
# Sample imputation looks fine and retains geographical structure pretty accurate.

# %% [markdown]
# ### Mexico and central america

# %%
imapCentralAmerica = {k: imap[k] for k in imap.keys() & {"central", "mex_w", "mex_e", "11th_area", "jamaica", "costa"}}
minmapCentralAmerica = {i: 0.5 for i in imapCentralAmerica}

# %%
pcaSampleCentral = ipa.pca(
    data=SNPS,
    imap=imapCentralAmerica,
    minmap=minmapCentralAmerica,
    mincov=0.75,
    impute_method="sample",
)
# Out:
# Samples: 116
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 129070
# Filtered (mincov): 3392855
# Filtered (minmap): 3153237
# Filtered (subsample invariant): 1686874
# Filtered (minor allele frequency): 0
# Filtered (combined): 3314330
# Sites after filtering: 12726
# Sites containing missing values: 12677 (99.61%)
# Missing values in SNP matrix: 302640 (20.50%)
# SNPs (total): 12726
# SNPs (unlinked): 2716
# Imputation: 'sampled'; (0, 1, 2) = 92.3%, 5.1%, 2.6%

# %%
pcaSampleCentral.run()
# Out:
# Subsampling SNPs: 2716/12726

# %%
# store the PC axes as a dataframe
df = pd.DataFrame(pcaSampleCentral.pcaxes[0], index=pcaSampleCentral.names)

# write the PC axes to a CSV file
df.to_csv("analysis_pca/pcaSampleCentral_analysis.csv")

# %%
#create a list of colors following imap order
colors = [region_colors[k] for k in imapCentralAmerica]

pcaSampleCentral.draw(colors=colors,
#                       outfile="pcaSampleCentralMay2021.svg"
                     )
# Out:
# (<toyplot.canvas.Canvas at 0x7f4cf2ad90d0>,
#  <toyplot.coordinates.Cartesian at 0x7f4cf2ad9150>)
# <div class="toyplot" id="t5a0bfc3485f04addb5599966ba8488ce" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="taf7067777e6947bca130562b024e5461" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 300.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t3110571e819b4c588d4b9cce82bd7d83"><clipPath id="t6af8688eb8014009a0cbada03b3d2c0f"><rect height="220.0" width="240.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t6af8688eb8014009a0cbada03b3d2c0f)"><g class="toyplot-mark-Point" id="t2f18aa1fd5724771b1d78b6d1bcff571"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(241.14487880619822, 147.29881154159992)"><title>__EJE_617</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(211.70684602285536, 136.46906162968136)"><title>__EJE_619</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(223.16351637599092, 144.1759594626799)"><title>__EJE_629</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(195.37914481307254, 155.74275295381366)"><title>__EJE_630</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(196.5378894696267, 151.68495000651245)"><title>__EJE_631</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(100.60229486938836, 99.48764672052405)"><title>acutifolium_DRY3_MEX_006</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(82.86184641995267, 66.43153261704984)"><title>acutifolium_MEX_005</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(92.0638610584568, 101.40089818216754)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(79.05907503888508, 104.92136446723285)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(95.4658073051225, 92.74973339893239)"><title>acutifolium_MJD_60</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(93.65444120597141, 107.35330358720869)"><title>acut ...

# %% [markdown]
# ### South america

# %%
imapSouthAmerica = {k: imap[k] for k in imap.keys() & {"col_w", "bol", "peru", "col_e", "ecu_n"}}
minmapSouthAmerica = {i: 0.5 for i in imapSouthAmerica}

# %%
pcaSampleSouth = ipa.pca(
    data=SNPS,
    imap=imapSouthAmerica,
    minmap=minmapSouthAmerica,
    mincov=0.75,
    impute_method="sample",
)
# Out:
# Samples: 62
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 72203
# Filtered (mincov): 3083036
# Filtered (minmap): 2670397
# Filtered (subsample invariant): 2525925
# Filtered (minor allele frequency): 0
# Filtered (combined): 3013568
# Sites after filtering: 85395
# Sites containing missing values: 85347 (99.94%)
# Missing values in SNP matrix: 941968 (17.79%)
# SNPs (total): 85395
# SNPs (unlinked): 12298
# Imputation: 'sampled'; (0, 1, 2) = 80.8%, 12.7%, 6.5%

# %%
pcaSampleSouth.run()
# Out:
# Subsampling SNPs: 12298/85395

# %%
# store the PC axes as a dataframe
df = pd.DataFrame(pcaSampleSouth.pcaxes[0], index=pcaSampleSouth.names)

# write the PC axes to a CSV file
df.to_csv("analysis_pca/pcaSampleSouth_analysis.csv")

# %%
#create a list of colors following imap order
colors = [region_colors[k] for k in imapSouthAmerica]

pcaSampleSouth.draw(colors=colors, 
#                     outfile="pcaSampleSouthMay2021.svg"
                   )
# Out:
# (<toyplot.canvas.Canvas at 0x7f4cf28a5950>,
#  <toyplot.coordinates.Cartesian at 0x7f4cf28a5910>)
# <div class="toyplot" id="tbbb9e5d6e8414e388c702b1a19e3e2b4" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="tb0b2001a881544fb8a3dee21e2f826a3" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 300.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t4b769b884a69431fa3c25186a25eb305"><clipPath id="t8f9df0c8f89c425f9effcef8a029bc67"><rect height="220.0" width="240.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t8f9df0c8f89c425f9effcef8a029bc67)"><g class="toyplot-mark-Point" id="t28e73bfa9a154d9ca2501a50e9572161"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(63.072591428049535, 214.16946773613398)"><title>anabaptista_PWS_2156</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(70.13535168118932, 242.82906515099182)"><title>anabaptista_PWS_2160</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(61.827661963900766, 231.31508817920218)"><title>anabaptista_PWS_2162</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(61.02423298809041, 243.96676788181287)"><title>anabaptista_PWS_2164</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(62.97397214552503, 237.70791131622275)"><title>anabaptista_PWS_2165</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(67.43213530106613, 232.28271313419498)"><title>anabaptista_PWS_2173</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(244.55296030015705, 178.21470440541063)"><title>ayavacense_PWS_3884</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(236.58418455915907, 182.18818611072533)"><title>ayavacense_PWS_3889</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(250.14783660158326, 188.04874412084482)"><title>ayavacense_PWS_3902</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(233.96578867017607, 179.53231208730966)"><title>ayavacense_PWS_3908</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,40%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(149.56683654338786, 157.62080190442035)"><title>ayavacense_PWS_4 ...

# %% [markdown]
# # Experimental area

# %% [markdown]
# ## Test with kmeans imputation

# %%
# testing kmeans imputation
# kmeans imputation
pcaK = ipa.pca(
    data=SNPS,
    imap=imap,
    minmap=minmap,
    mincov=0.99,
    impute_method=11, #I am puting here the number of endemism areas
)
# Out:
# Kmeans clustering: iter=0, K=11, mincov=0.9, minmap={'global': 0.99}
# Samples: 178
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 193270
# Filtered (mincov): 3417640
# Filtered (minmap): 3419591
# Filtered (subsample invariant): 957960
# Filtered (minor allele frequency): 0
# Filtered (combined): 3407348
# Sites after filtering: 50
# Sites containing missing values: 40 (80.00%)
# Missing values in SNP matrix: 40 (0.45%)
# SNPs (total): 50
# SNPs (unlinked): 21
# Imputation: 'sampled'; (0, 1, 2) = 90.0%, 2.5%, 7.5%
# {0: ['__EJE_617', '__EJE_629', '__EJE_630', 'acutifolium_DRY3_MEX_006', 'acutifolium_MEX_005', 'acutifolium_MJD_011_tuton_111816', 'acutifolium_MJD_012_tuton_111816', 'acutifolium_MJD_60', 'acutifolium_PWS_3050', 'acutifolium_PWS_3059', 'alpinum_PWS_3924', 'anabaptista_PWS_2156', 'anabaptista_PWS_2160', 'anabaptista_PWS_2162', 'anabaptista_PWS_2164', 'anabaptista_PWS_2165', 'anabaptista_PWS_2173', 'ayavacense_PWS_3884', 'ayavacense_PWS_3889', 'ayavacense_PWS_3902', 'ayavacense_PWS_4000', 'ayavacense_PWS_4003', 'ayavacense_PWS_4006', 'blandum_EJE_618', 'blandum_EJE_621', 'blandum_PWS_3088', 'caudatum_MJD_64', 'caudatum_PWS_3216', 'caudatum_PWS_3223', 'caudatum_PWS_3223_M1', 'ciliatum_C1', 'ciliatum_PWS_3220', 'ciliatum_PWS_3225', 'ciliatum_SH2', 'costaricanum_MJD_85', 'disjunctum_EJE_615', 'disjunctum_MJD_66', 'divaricatum_PWS_1773', 'fuscum-shiny_EJE_602', 'fuscum_EJE_608', 'fuscum_EJE_609', 'fuscum_MJD_007_tuton_111816', 'fuscum_MJD_013_tuton_111816', 'fuscum_MJD_014_tuton_111816', 'fuscum_PWS_3054', 'fuscum_PWS_3058', 'fuscum_shiny_EJE_604', 'hallii_PWS_1634', 'hallii_PWS_1830', 'hallii_PWS_2180', 'hartwegii_EJE_612', 'hartwegii_PWS_3190', 'hybrid_MJD_001_tuton_111716', 'hybrid_MJD_003_tuton_111716', 'hybrid_MJD_005_tuton_111716', 'hybrid_MJD_006_tuton_111716', 'hybrid_MJD_010_tuton_111816', 'hybrid_PWS_3206', 'hybrid_PWS_3208', 'hybrid_huatla_6', 'jamesonii_PWS_1636', 'jamesonii_PWS_1656', 'jucundum_HUL_H_31.1', 'jucundum_MJD_69', 'jucundum_MKM_12', 'jucundum_MKM_13', 'jucundum_MKM_14', 'jucundum_PWS_3107', 'jucundum_PWS_3188', 'lasiophyllum_PWS_2174', 'lasiophyllum_PWS_2175', 'loesnerii_MJD_75', 'microcarpum_MJD_76', 'microcarpum_PWS_3202', 'microcarpum_PWS_3210', 'microcarpum_PWS_3226', 'microcarpum_PWS_3227', 'microcarpum_V1', 'microcarpum_ZA2', 'microcarpum_ZA4', 'microphyllum_DE_001', 'microphyllum_DE_002', 'microphyllum_DE_003', 'obtusatum_PWS_3100', 'obtusatum_Tzont', 'pastasanum_PWS_1799', 'pichinchense_PWS_1621', 'pichinchense_PWS_1669', 'reticulatum_PWS_1706', 'reticulatum_PWS_1719', 'reticulatum_PWS_1735', 'reticulatum_PWS_1737', 'seemenii_PWS_3895', 'seemenii_PWS_3900', 'stellato-tomentosum_MJD_83', 'stenocalyx_EJE_606', 'stenocalyx_PWS_3234', 'subsessile_PWS_2171', 'subsessile_PWS_2172', 'sulcatum_MEX_003', 'sulcatum_MEX_004', 'sulcatum_MJD_79', 'tiliafolium_PWS_3205', 'tiliafolium_PWS_3209', 'tiliafolium_PWS_3217', 'tiliafolium_PWS_3222', 'tiliafolium_PWS_3230', 'tinoides_PWS_2151', 'tinoides_PWS_2152', 'tinoides_PWS_2155', 'tinoides_PWS_2157', 'tinoides_PWS_2158', 'tinoides_PWS_2168', 'tinoides_PWS_2170C', 'tinoides_PWS_2170D', 'tinoides_PWS_2170E', 'tinoides_PWS_2170F', 'tinoides_PWS_2170G', 'tinoides_PWS_2176', 'tinoides_PWS_2177', 'triphyllum_Edwards_2014_04', 'triphyllum_PWS_1682', 'triphyllum_PWS_1757', 'triphyllum_PWS_1769', 'triphyllum_PWS_1783', 'triphyllum_WC_285', 'triphyllum_WC_286', 'triphyllum_WC_287B', 'triphyllum_WC_287C', 'triphyllum_WC_287D', 'triphyllum_WC_288C', 'triphyllum_WC_288E', 'triphyllum_WC_288b', 'triphyllum_WC_299', 'villosum_PWS_3918'], 1: ['hartwegii_EJE_642', 'hartwegii_PWS_3108', 'hartwegii_PWS_3186', 'hartwegii_PWS_3193', 'hartwegii_PWS_3194', 'hartwegii_PWS_3195', 'jucundum_EJE_634', 'jucundum_EJE_636', 'jucundum_MKM_11', 'jucundum_MKM_15', 'jucundum_MKM_16', 'jucundum_MKM_17', 'jucundum_MKM_18', 'jucundum_MKM_20', 'lautum_EJE_638', 'lautum_MJD_73', 'lautum_MKM_1', 'lautum_MKM_2', 'lautum_MKM_23', 'lautum_MKM_24', 'lautum_MKM_25', 'lautum_MKM_26', 'lautum_MKM_3', 'lautum_MKM_9', 'lautum_PWS_3105', 'lautum_PWS_3106', 'lautum_PWS_3189', 'lautum_PWS_3191', 'obtusatum_HUAT_4'], 2: ['triphyllum_PWS_2179'], 3: ['ayavacense_PWS_3908', 'hybrid_MJD_002_tuton_111716', 'reticulatum_PWS_1702', 'stenocalyx_EJE_607'], 4: ['hybrid_MJD_009_tuton_111816'], 5: ['hartwegii_MJD_81', 'tiliafolium_jucundum_2_oaxaca_2017'], 6: ['subsessile_PWS_2169'], 7: ['__EJE_619'], 8: ['caudatum_PWS_3211', 'caudatum_PWS_3221'], 9: ['fuscum_shiny_EJE_603'], 10: ['__EJE_631']}
#
# Kmeans clustering: iter=1, K=11, mincov=0.9225, minmap={0: 0.99, 1: 0.99, 2: 0.99, 3: 0.99, 4: 0.99, 5: 0.99, 6: 0.99, 7: 0.99, 8: 0.99, 9: 0.99, 10: 0.99}
# Samples: 178
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 193270
# Filtered (mincov): 3418179
# Filtered (minmap): 3419591
# Filtered (subsample invariant): 957960
# Filtered (minor allele frequency): 0
# Filtered (combined): 3407348
# Sites after filtering: 50
# Sites containing missing values: 40 (80.00%)
# Missing values in SNP matrix: 40 (0.45%)
# SNPs (total): 50
# SNPs (unlinked): 21
# Imputation: 'sampled'; (0, 1, 2) = 90.0%, 0.0%, 10.0%
# {0: ['__EJE_630', 'acutifolium_DRY3_MEX_006', 'acutifolium_MEX_005', 'acutifolium_MJD_011_tuton_111816', 'acutifolium_MJD_012_tuton_111816', 'acutifolium_MJD_60', 'acutifolium_PWS_3050', 'acutifolium_PWS_3059', 'alpinum_PWS_3924', 'anabaptista_PWS_2156', 'anabaptista_PWS_2160', 'anabaptista_PWS_2162', 'anabaptista_PWS_2164', 'anabaptista_PWS_2165', 'anabaptista_PWS_2173', 'ayavacense_PWS_3884', 'ayavacense_PWS_3889', 'ayavacense_PWS_3902', 'ayavacense_PWS_3908', 'ayavacense_PWS_4000', 'ayavacense_PWS_4003', 'ayavacense_PWS_4006', 'blandum_EJE_618', 'blandum_EJE_621', 'blandum_PWS_3088', 'caudatum_MJD_64', 'caudatum_PWS_3211', 'caudatum_PWS_3216', 'caudatum_PWS_3221', 'caudatum_PWS_3223', 'caudatum_PWS_3223_M1', 'ciliatum_C1', 'ciliatum_SH2', 'costaricanum_MJD_85', 'disjunctum_EJE_615', 'disjunctum_MJD_66', 'divaricatum_PWS_1773', 'fuscum-shiny_EJE_602', 'fuscum_EJE_608', 'fuscum_MJD_007_tuton_111816', 'fuscum_MJD_013_tuton_111816', 'fuscum_MJD_014_tuton_111816', 'fuscum_PWS_3054', 'fuscum_PWS_3058', 'fuscum_shiny_EJE_603', 'fuscum_shiny_EJE_604', 'hallii_PWS_1634', 'hallii_PWS_1830', 'hallii_PWS_2180', 'hartwegii_EJE_612', 'hartwegii_PWS_3190', 'hybrid_MJD_001_tuton_111716', 'hybrid_MJD_002_tuton_111716', 'hybrid_MJD_003_tuton_111716', 'hybrid_MJD_005_tuton_111716', 'hybrid_MJD_006_tuton_111716', 'hybrid_MJD_009_tuton_111816', 'hybrid_MJD_010_tuton_111816', 'hybrid_PWS_3206', 'hybrid_PWS_3208', 'hybrid_huatla_6', 'jamesonii_PWS_1636', 'jamesonii_PWS_1656', 'jucundum_EJE_634', 'jucundum_EJE_636', 'jucundum_HUL_H_31.1', 'jucundum_MJD_69', 'jucundum_MKM_11', 'jucundum_MKM_12', 'jucundum_MKM_13', 'jucundum_MKM_14', 'jucundum_MKM_15', 'jucundum_MKM_16', 'jucundum_MKM_17', 'jucundum_MKM_18', 'jucundum_MKM_20', 'jucundum_PWS_3107', 'jucundum_PWS_3188', 'lasiophyllum_PWS_2174', 'lasiophyllum_PWS_2175', 'lautum_EJE_638', 'lautum_MJD_73', 'lautum_MKM_1', 'lautum_MKM_2', 'lautum_MKM_23', 'lautum_MKM_24', 'lautum_MKM_25', 'lautum_MKM_26', 'lautum_MKM_3', 'lautum_MKM_9', 'lautum_PWS_3105', 'lautum_PWS_3106', 'lautum_PWS_3189', 'lautum_PWS_3191', 'loesnerii_MJD_75', 'microcarpum_MJD_76', 'microcarpum_PWS_3202', 'microcarpum_PWS_3210', 'microcarpum_PWS_3226', 'microcarpum_PWS_3227', 'microcarpum_V1', 'microcarpum_ZA2', 'microcarpum_ZA4', 'microphyllum_DE_001', 'microphyllum_DE_002', 'microphyllum_DE_003', 'obtusatum_PWS_3100', 'obtusatum_Tzont', 'pastasanum_PWS_1799', 'pichinchense_PWS_1621', 'reticulatum_PWS_1702', 'reticulatum_PWS_1706', 'reticulatum_PWS_1719', 'reticulatum_PWS_1735', 'reticulatum_PWS_1737', 'seemenii_PWS_3895', 'seemenii_PWS_3900', 'stellato-tomentosum_MJD_83', 'stenocalyx_EJE_606', 'stenocalyx_EJE_607', 'stenocalyx_PWS_3234', 'sulcatum_MEX_003', 'sulcatum_MEX_004', 'sulcatum_MJD_79', 'tiliafolium_PWS_3205', 'tiliafolium_PWS_3209', 'tiliafolium_PWS_3217', 'tiliafolium_PWS_3222', 'tiliafolium_PWS_3230', 'tinoides_PWS_2152', 'tinoides_PWS_2155', 'tinoides_PWS_2157', 'tinoides_PWS_2158', 'tinoides_PWS_2168', 'tinoides_PWS_2170C', 'tinoides_PWS_2170D', 'tinoides_PWS_2170E', 'tinoides_PWS_2170F', 'tinoides_PWS_2176', 'tinoides_PWS_2177', 'triphyllum_Edwards_2014_04', 'triphyllum_PWS_1682', 'triphyllum_PWS_1757', 'triphyllum_PWS_1769', 'triphyllum_PWS_1783', 'triphyllum_PWS_2179', 'triphyllum_WC_285', 'triphyllum_WC_286', 'triphyllum_WC_287B', 'triphyllum_WC_287C', 'triphyllum_WC_287D', 'triphyllum_WC_288C', 'triphyllum_WC_288E', 'triphyllum_WC_288b', 'triphyllum_WC_299', 'villosum_PWS_3918'], 1: ['__EJE_617', 'hartwegii_EJE_642', 'hartwegii_PWS_3108', 'hartwegii_PWS_3186', 'hartwegii_PWS_3193', 'hartwegii_PWS_3194', 'hartwegii_PWS_3195', 'subsessile_PWS_2171', 'subsessile_PWS_2172', 'tinoides_PWS_2151', 'tinoides_PWS_2170G'], 2: ['hartwegii_MJD_81', 'tiliafolium_jucundum_2_oaxaca_2017'], 3: ['pichinchense_PWS_1669'], 4: ['__EJE_619'], 5: ['subsessile_PWS_2169'], 6: ['obtusatum_HUAT_4'], 7: ['__EJE_629'], 8: ['fuscum_EJE_609'], 9: ['ciliatum_PWS_3220', 'ciliatum_PWS_3225'], 10: ['__EJE_631']}
#
# Kmeans clustering: iter=2, K=11, mincov=0.9450000000000001, minmap={0: 0.99, 1: 0.99, 2: 0.99, 3: 0.99, 4: 0.99, 5: 0.99, 6: 0.99, 7: 0.99, 8: 0.99, 9: 0.99, 10: 0.99}
# Samples: 178
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 193270
# Filtered (mincov): 3418672
# Filtered (minmap): 3419591
# Filtered (subsample invariant): 957960
# Filtered (minor allele frequency): 0
# Filtered (combined): 3407348
# Sites after filtering: 50
# Sites containing missing values: 40 (80.00%)
# Missing values in SNP matrix: 40 (0.45%)
# SNPs (total): 50
# SNPs (unlinked): 21
# Imputation: 'sampled'; (0, 1, 2) = 92.5%, 0.0%, 7.5%
# {0: ['ayavacense_PWS_3884', 'ayavacense_PWS_3889', 'ayavacense_PWS_3902', 'ayavacense_PWS_3908', 'ayavacense_PWS_4000', 'ayavacense_PWS_4003', 'ayavacense_PWS_4006', 'divaricatum_PWS_1773', 'hallii_PWS_2180', 'jamesonii_PWS_1656', 'lasiophyllum_PWS_2174', 'lasiophyllum_PWS_2175', 'pastasanum_PWS_1799', 'pichinchense_PWS_1621', 'reticulatum_PWS_1702', 'reticulatum_PWS_1706', 'reticulatum_PWS_1735', 'reticulatum_PWS_1737', 'seemenii_PWS_3895', 'seemenii_PWS_3900', 'tinoides_PWS_2176', 'tinoides_PWS_2177', 'triphyllum_Edwards_2014_04', 'triphyllum_PWS_1682', 'triphyllum_PWS_1757', 'triphyllum_PWS_1769', 'triphyllum_PWS_1783', 'triphyllum_PWS_2179', 'triphyllum_WC_285', 'triphyllum_WC_286', 'triphyllum_WC_287B', 'triphyllum_WC_287C', 'triphyllum_WC_287D', 'triphyllum_WC_288C', 'triphyllum_WC_288E', 'triphyllum_WC_299'], 1: ['__EJE_617', '__EJE_629', '__EJE_630', '__EJE_631', 'acutifolium_DRY3_MEX_006', 'acutifolium_MEX_005', 'acutifolium_MJD_011_tuton_111816', 'acutifolium_MJD_012_tuton_111816', 'acutifolium_MJD_60', 'acutifolium_PWS_3050', 'acutifolium_PWS_3059', 'alpinum_PWS_3924', 'blandum_EJE_618', 'blandum_EJE_621', 'blandum_PWS_3088', 'caudatum_MJD_64', 'caudatum_PWS_3211', 'caudatum_PWS_3216', 'caudatum_PWS_3221', 'caudatum_PWS_3223', 'caudatum_PWS_3223_M1', 'ciliatum_C1', 'ciliatum_SH2', 'costaricanum_MJD_85', 'disjunctum_EJE_615', 'disjunctum_MJD_66', 'fuscum-shiny_EJE_602', 'fuscum_EJE_608', 'fuscum_EJE_609', 'fuscum_MJD_007_tuton_111816', 'fuscum_MJD_013_tuton_111816', 'fuscum_MJD_014_tuton_111816', 'fuscum_PWS_3054', 'fuscum_PWS_3058', 'fuscum_shiny_EJE_603', 'fuscum_shiny_EJE_604', 'hallii_PWS_1634', 'hallii_PWS_1830', 'hartwegii_EJE_612', 'hartwegii_PWS_3190', 'hybrid_MJD_001_tuton_111716', 'hybrid_MJD_002_tuton_111716', 'hybrid_MJD_003_tuton_111716', 'hybrid_MJD_005_tuton_111716', 'hybrid_MJD_006_tuton_111716', 'hybrid_MJD_009_tuton_111816', 'hybrid_MJD_010_tuton_111816', 'hybrid_PWS_3206', 'hybrid_PWS_3208', 'hybrid_huatla_6', 'jucundum_HUL_H_31.1', 'jucundum_MKM_12', 'jucundum_MKM_13', 'jucundum_MKM_14', 'jucundum_PWS_3107', 'jucundum_PWS_3188', 'loesnerii_MJD_75', 'microcarpum_MJD_76', 'microcarpum_PWS_3202', 'microcarpum_PWS_3210', 'microcarpum_PWS_3226', 'microcarpum_PWS_3227', 'microcarpum_V1', 'microcarpum_ZA2', 'microcarpum_ZA4', 'microphyllum_DE_001', 'microphyllum_DE_002', 'microphyllum_DE_003', 'obtusatum_PWS_3100', 'obtusatum_Tzont', 'stellato-tomentosum_MJD_83', 'stenocalyx_EJE_606', 'stenocalyx_EJE_607', 'stenocalyx_PWS_3234', 'sulcatum_MEX_003', 'sulcatum_MEX_004', 'sulcatum_MJD_79', 'tiliafolium_PWS_3205', 'tiliafolium_PWS_3209', 'tiliafolium_PWS_3217', 'tiliafolium_PWS_3222', 'tiliafolium_PWS_3230', 'triphyllum_WC_288b', 'villosum_PWS_3918'], 2: ['anabaptista_PWS_2156', 'anabaptista_PWS_2160', 'anabaptista_PWS_2162', 'anabaptista_PWS_2164', 'anabaptista_PWS_2165', 'anabaptista_PWS_2173', 'jamesonii_PWS_1636', 'subsessile_PWS_2169', 'subsessile_PWS_2171', 'subsessile_PWS_2172', 'tinoides_PWS_2151', 'tinoides_PWS_2152', 'tinoides_PWS_2155', 'tinoides_PWS_2157', 'tinoides_PWS_2158', 'tinoides_PWS_2168', 'tinoides_PWS_2170C', 'tinoides_PWS_2170D', 'tinoides_PWS_2170E', 'tinoides_PWS_2170F', 'tinoides_PWS_2170G'], 3: ['hartwegii_EJE_642', 'hartwegii_PWS_3108', 'hartwegii_PWS_3186', 'hartwegii_PWS_3193', 'hartwegii_PWS_3194', 'hartwegii_PWS_3195', 'jucundum_EJE_634', 'jucundum_EJE_636', 'jucundum_MKM_11', 'jucundum_MKM_15', 'jucundum_MKM_16', 'jucundum_MKM_17', 'jucundum_MKM_18', 'jucundum_MKM_20', 'lautum_EJE_638', 'lautum_MJD_73', 'lautum_MKM_1', 'lautum_MKM_2', 'lautum_MKM_23', 'lautum_MKM_24', 'lautum_MKM_25', 'lautum_MKM_26', 'lautum_MKM_3', 'lautum_MKM_9', 'lautum_PWS_3105', 'lautum_PWS_3106', 'lautum_PWS_3189', 'lautum_PWS_3191', 'obtusatum_HUAT_4'], 4: ['jucundum_MJD_69'], 5: ['pichinchense_PWS_1669'], 6: ['hartwegii_MJD_81'], 7: ['reticulatum_PWS_1719'], 8: ['ciliatum_PWS_3220', 'ciliatum_PWS_3225'], 9: ['__EJE_619'], 10: ['tiliafolium_jucundum_2_oaxaca_2017']}
#
# Kmeans clustering: iter=3, K=11, mincov=0.9675, minmap={0: 0.99, 1: 0.99, 2: 0.99, 3: 0.99, 4: 0.99, 5: 0.99, 6: 0.99, 7: 0.99, 8: 0.99, 9: 0.99, 10: 0.99}
# Samples: 178
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 193270
# Filtered (mincov): 3419152
# Filtered (minmap): 3419650
# Filtered (subsample invariant): 957960
# Filtered (minor allele frequency): 0
# Filtered (combined): 3407388
# Sites after filtering: 10
# Sites containing missing values: 0 (0.00%)
# Missing values in SNP matrix: 0 (0.00%)
# SNPs (total): 10
# SNPs (unlinked): 6
# Imputation: 'sampled'; (0, 1, 2) = nan%, nan%, nan%
# {1: ['blandum_EJE_618'], 2: ['caudatum_PWS_3211', 'caudatum_PWS_3221'], 3: ['subsessile_PWS_2169'], 4: ['lautum_MKM_25'], 5: ['lautum_MKM_3'], 6: ['__EJE_619'], 8: ['__EJE_629'], 9: ['__EJE_631'], 10: ['__EJE_617', '__EJE_630', 'acutifolium_DRY3_MEX_006', 'acutifolium_MEX_005', 'acutifolium_MJD_011_tuton_111816', 'acutifolium_MJD_012_tuton_111816', 'acutifolium_MJD_60', 'acutifolium_PWS_3050', 'acutifolium_PWS_3059', 'alpinum_PWS_3924', 'anabaptista_PWS_2156', 'anabaptista_PWS_2160', 'anabaptista_PWS_2162', 'anabaptista_PWS_2164', 'anabaptista_PWS_2165', 'anabaptista_PWS_2173', 'ayavacense_PWS_3884', 'ayavacense_PWS_3889', 'ayavacense_PWS_3902', 'ayavacense_PWS_3908', 'ayavacense_PWS_4000', 'ayavacense_PWS_4003', 'ayavacense_PWS_4006', 'blandum_EJE_621', 'blandum_PWS_3088', 'caudatum_MJD_64', 'caudatum_PWS_3216', 'caudatum_PWS_3223', 'caudatum_PWS_3223_M1', 'ciliatum_C1', 'ciliatum_PWS_3220', 'ciliatum_PWS_3225', 'ciliatum_SH2', 'costaricanum_MJD_85', 'disjunctum_EJE_615', 'disjunctum_MJD_66', 'divaricatum_PWS_1773', 'fuscum-shiny_EJE_602', 'fuscum_EJE_608', 'fuscum_EJE_609', 'fuscum_MJD_007_tuton_111816', 'fuscum_MJD_013_tuton_111816', 'fuscum_MJD_014_tuton_111816', 'fuscum_PWS_3054', 'fuscum_PWS_3058', 'fuscum_shiny_EJE_603', 'fuscum_shiny_EJE_604', 'hallii_PWS_1634', 'hallii_PWS_1830', 'hallii_PWS_2180', 'hartwegii_EJE_612', 'hartwegii_EJE_642', 'hartwegii_MJD_81', 'hartwegii_PWS_3108', 'hartwegii_PWS_3186', 'hartwegii_PWS_3190', 'hartwegii_PWS_3193', 'hartwegii_PWS_3194', 'hartwegii_PWS_3195', 'hybrid_MJD_001_tuton_111716', 'hybrid_MJD_002_tuton_111716', 'hybrid_MJD_003_tuton_111716', 'hybrid_MJD_005_tuton_111716', 'hybrid_MJD_006_tuton_111716', 'hybrid_MJD_009_tuton_111816', 'hybrid_MJD_010_tuton_111816', 'hybrid_PWS_3206', 'hybrid_PWS_3208', 'hybrid_huatla_6', 'jamesonii_PWS_1636', 'jamesonii_PWS_1656', 'jucundum_EJE_634', 'jucundum_EJE_636', 'jucundum_HUL_H_31.1', 'jucundum_MJD_69', 'jucundum_MKM_11', 'jucundum_MKM_12', 'jucundum_MKM_13', 'jucundum_MKM_14', 'jucundum_MKM_15', 'jucundum_MKM_16', 'jucundum_MKM_17', 'jucundum_MKM_18', 'jucundum_MKM_20', 'jucundum_PWS_3107', 'jucundum_PWS_3188', 'lasiophyllum_PWS_2174', 'lasiophyllum_PWS_2175', 'lautum_EJE_638', 'lautum_MJD_73', 'lautum_MKM_1', 'lautum_MKM_2', 'lautum_MKM_23', 'lautum_MKM_24', 'lautum_MKM_26', 'lautum_MKM_9', 'lautum_PWS_3105', 'lautum_PWS_3106', 'lautum_PWS_3189', 'lautum_PWS_3191', 'loesnerii_MJD_75', 'microcarpum_MJD_76', 'microcarpum_PWS_3202', 'microcarpum_PWS_3210', 'microcarpum_PWS_3226', 'microcarpum_PWS_3227', 'microcarpum_V1', 'microcarpum_ZA2', 'microcarpum_ZA4', 'microphyllum_DE_001', 'microphyllum_DE_002', 'microphyllum_DE_003', 'obtusatum_HUAT_4', 'obtusatum_PWS_3100', 'obtusatum_Tzont', 'pastasanum_PWS_1799', 'pichinchense_PWS_1621', 'pichinchense_PWS_1669', 'reticulatum_PWS_1702', 'reticulatum_PWS_1706', 'reticulatum_PWS_1719', 'reticulatum_PWS_1735', 'reticulatum_PWS_1737', 'seemenii_PWS_3895', 'seemenii_PWS_3900', 'stellato-tomentosum_MJD_83', 'stenocalyx_EJE_606', 'stenocalyx_EJE_607', 'stenocalyx_PWS_3234', 'subsessile_PWS_2171', 'subsessile_PWS_2172', 'sulcatum_MEX_003', 'sulcatum_MEX_004', 'sulcatum_MJD_79', 'tiliafolium_PWS_3205', 'tiliafolium_PWS_3209', 'tiliafolium_PWS_3217', 'tiliafolium_PWS_3222', 'tiliafolium_PWS_3230', 'tiliafolium_jucundum_2_oaxaca_2017', 'tinoides_PWS_2151', 'tinoides_PWS_2152', 'tinoides_PWS_2155', 'tinoides_PWS_2157', 'tinoides_PWS_2158', 'tinoides_PWS_2168', 'tinoides_PWS_2170C', 'tinoides_PWS_2170D', 'tinoides_PWS_2170E', 'tinoides_PWS_2170F', 'tinoides_PWS_2170G', 'tinoides_PWS_2176', 'tinoides_PWS_2177', 'triphyllum_Edwards_2014_04', 'triphyllum_PWS_1682', 'triphyllum_PWS_1757', 'triphyllum_PWS_1769', 'triphyllum_PWS_1783', 'triphyllum_PWS_2179', 'triphyllum_WC_285', 'triphyllum_WC_286', 'triphyllum_WC_287B', 'triphyllum_WC_287C', 'triphyllum_WC_287D', 'triphyllum_WC_288C', 'triphyllum_WC_288E', 'triphyllum_WC_288b', 'triphyllum_WC_299', 'villosum_PWS_3918']}
#
# Kmeans clustering: iter=4, K=11, mincov=0.99, minmap={1: 0.99, 2: 0.99, 3: 0.99, 4: 0.99, 5: 0.99, 6: 0.99, 8: 0.99, 9: 0.99, 10: 0.99}
# /home/carlos/ipyrad/ipyrad/analysis/snps_imputer.py:118: RuntimeWarning: invalid value encountered in long_scalars
#   100 * np.sum(imputed == 0) / imputed.size,
# /home/carlos/ipyrad/ipyrad/analysis/snps_imputer.py:119: RuntimeWarning: invalid value encountered in long_scalars
#   100 * np.sum(imputed == 1) / imputed.size,
# /home/carlos/ipyrad/ipyrad/analysis/snps_imputer.py:120: RuntimeWarning: invalid value encountered in long_scalars
#   100 * np.sum(imputed == 2) / imputed.size,
# /home/carlos/ipyrad/ipyrad/analysis/pca.py:282: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   kmeans_model.fit(pcadata)
# Samples: 178
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 193270
# Filtered (mincov): 3419591
# Filtered (minmap): 3419591
# Filtered (subsample invariant): 957960
# Filtered (minor allele frequency): 0
# Filtered (combined): 3407348
# Sites after filtering: 50
# Sites containing missing values: 40 (80.00%)
# Missing values in SNP matrix: 40 (0.45%)
# SNPs (total): 50
# SNPs (unlinked): 21
# Imputation: 'sampled'; (0, 1, 2) = 90.0%, 2.5%, 7.5%

# %%
# run and draw results for kmeans clustering
pcaK.run()
# Out:
# Subsampling SNPs: 21/50

# %%
# store the PC axes as a dataframe
df = pd.DataFrame(pcaK.pcaxes[0], index=pcaK.names)

# write the PC axes to a CSV file
df.to_csv("analysis_pca/pcaK_analysis.csv")

# %%
pcaK.draw(0, 2);
# Out:
# <div class="toyplot" id="t5957eb81962d49598cf9a159523f867a" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t888fc65be01a4bfc8dcfa67f9eeabc8b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 300.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc30ba0b1da6c4653b2468989bb44caee"><clipPath id="tc191724005e44cc0b210910a04ae2284"><rect height="220.0" width="240.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tc191724005e44cc0b210910a04ae2284)"><g class="toyplot-mark-Point" id="t9b1da56f4dd74aa0b994d5628296304f"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(234.33195193426988, 246.84141387826654)"><title>__EJE_617</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(241.93346073881605, 247.46534766684422)"><title>__EJE_619</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>__EJE_629</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.30384794988767, 247.93995026497655)"><title>__EJE_630</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.30384794988767, 247.93995026497655)"><title>__EJE_631</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(28.3%,63.1%,70.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>acutifolium_DRY3_MEX_006</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(28.3%,63.1%,70.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>acutifolium_MEX_005</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(28.3%,63.1%,70.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(28.3%,63.1%,70.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(28.3%,63.1%,70.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>acutifolium_MJD_60</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(28.3%,63.1%,70.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(51.70018815071253, 247.50855133993758)"><title>acutifolium ...

# %% [markdown]
# kimputation is kinda messy. with mincov 0.75

# %% [markdown]
# ## Imputation without interference of imap
#
# In this test the imputation is base on the entire matrix and not in the subset in the imap.
#
# If this pca is similar to those with sample imputation,  we can be sure that those results are not an artifact of our imputation method

# %%
# testi g no imputation
pcaNone = ipa.pca(
    data=SNPS,
    imap=None,
    minmap=None,
    mincov=0.5,
    impute_method="sample",
)
# Out:
# Samples: 274
# Sites before filtering: 3419673
# Filtered (indels): 0
# Filtered (bi-allel): 278880
# Filtered (mincov): 2529537
# Filtered (minmap): 0
# Filtered (subsample invariant): 6
# Filtered (minor allele frequency): 0
# Filtered (combined): 2628555
# Sites after filtering: 796202
# Sites containing missing values: 796193 (100.00%)
# Missing values in SNP matrix: 88550963 (40.59%)
# SNPs (total): 796202
# SNPs (unlinked): 45280
# Imputation: 'sampled'; (0, 1, 2) = 93.3%, 4.8%, 1.8%

# %%
pcaNone.run()
# Out:
# Subsampling SNPs: 45280/796202

# %%
##import collections to create an empty dict
from collections import defaultdict


#create empty dict
imap_test = defaultdict(list)

imap_test["excluded"] = []


#go row by row
for index, row in fulldata.iterrows():
    #only check fulldataset specimens
    if row["full_dataset_withAyava"]:
        if row["Last_valid_name"] != "dentatum": 
            sp = row["Last_valid_name"]
            region = regions[regions["Species"] == sp]["Region"].values[0]
            imap_test[region].append(row["NameInAssembly"])

# %%
import h5py
w = h5py.File(SNPS,'r')

# %%
names_in_h5 = w["snps"].attrs["names"]
w.close()

# %%
t = []
for i in imap_test.values():
    t.extend(i)

# %%
imap_test["central"].append("reference")


for i in names_in_h5:
    if i.decode("utf-8") not in t:
        imap_test["excluded"].append(i.decode("utf-8"))

# %%
pcaNone.draw(imap=imap_test, cycle=10)
# Out:
# (<toyplot.canvas.Canvas at 0x7f6da8e7f610>,
#  <toyplot.coordinates.Cartesian at 0x7f6da8e7fd50>)
# <div class="toyplot" id="t9cdd462228214252acfa3247bc35cb87" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t8f9328a97c314720959f83308a595438" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 300.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tb4d0fbbf25e54735b4cda0985adc30c5"><clipPath id="t0440369190bd430db3ecd387f236bb03"><rect height="220.0" width="240.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t0440369190bd430db3ecd387f236bb03)"><g class="toyplot-mark-Point" id="t35cd14ea41d4470798096559aa9e7ff5"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(21.9%,55.9%,73.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(92.49243898326591, 245.54695835223873)"><title>reference</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(120.48399257539224, 195.68090797060088)"><title>_MJD_11_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(118.46524321128504, 199.6734418137659)"><title>_MJD_4_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(89.32976847392938, 94.45476004279543)"><title>_MJD_5_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(97.97858507698086, 106.17508522336313)"><title>_MJD_6_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(135.63073326911854, 149.20206769587577)"><title>_MJD_7_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(104.28029644229888, 103.67256465039006)"><title>_MJD_8_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(121.17657833444872, 211.52329997266304)"><title>_MJD_Yashtinin_hybrid_2019</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(21.9%,55.9%,73.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(139.48597074181393, 179.3586454002546)"><title>__EJE_617</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(21.9%,55.9%,73.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(140.54718207788275, 191.31713310026737)"><title>__EJE_619</title><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(21.9%,55.9%,73.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" transform="translate(134.74820239676953, 189.34033766666258)"><title>__EJE_629</title><circle r="5.0"></circle></g><g class="toyplo ...

# %% [markdown]
# This result shows that the organization is pretty accurate to the general pca done with sample imputation. Because our hdf5 file contain some samples that were not included in this analysis, some excluded specimens are showed as purple boxes. Howerver groups like mex_w and mex_e are separated and a big pack of south america still is separated from the latter.
#
# I am pretty sure that imputation is not the cause of the pattern for that the sample imputation pca is very accurate depite of the missing data imputed (17-21%).
