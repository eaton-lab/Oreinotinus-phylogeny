# %% [markdown]
# ## Viburnum Oreinotinus PCAs
# And other dimensionality reduction methods.

# %%
import dbgdrive
import ipyrad.analysis as ipa
print(ipa.__version__)
# Out:
# 1.0.0-alpha

# %% [markdown]
# ### Assembled dataset

# %%
DATA = (
    "/home/deren/Documents/Viburnum-Oreinotinus/assembly_hic_feb/"
    "full_dataset_outfiles/full_dataset.snps.hdf5"
)

# %% [markdown]
# ### Metadata

# %%
fulldata = dbgdrive.get_database(
    sheet_name='sample-data', 
    id_spreadsheet='1mnbZVtnI4AQDseWaawV2au4bNyFD_B9M0z8REMXbOcs',
    api_key='AIzaSyDh0Apfm562l_vlXOYizzyiZjAbFGYEnzo',
)

# %%
# those regions correspond to the Early March 2021 version, not with late march or april
regions = dbgdrive.get_database(
    sheet_name='regions',
    id_spreadsheet='1mnbZVtnI4AQDseWaawV2au4bNyFD_B9M0z8REMXbOcs',
    api_key='AIzaSyDh0Apfm562l_vlXOYizzyiZjAbFGYEnzo',
)

# %%
region_colors = {}
for row, region in enumerate(regions["RegionUnique"]):
    if region != None: 
        region_colors[region] = regions["ColorRegionUnique"][row]

# %%
region_colors
# Out:
# {'11th_area': '#00966D',
#  'bol': '#d4ff2a',
#  'central': '#d35f5f',
#  'col_e': '#5555ff',
#  'col_w': '#66ff00',
#  'costa': '#501644',
#  'ecu_n': '#de87cd',
#  'jamaica': '#ffd42a',
#  'mex_e': '#a8ffaa',
#  'mex_w': '#87cdde',
#  'out': '#a09999',
#  'peru': '#ff6600'}

# %% [markdown]
# ### Population assignments

# %%
imap = {}
for index, row in fulldata.iterrows():
    # only check fulldataset specimens
    if row["full_dataset_withAyava"]:
        if row["Last_valid_name"] != "dentatum": 
            sp = row["Last_valid_name"]
            region = regions[regions["Species"] == sp]["Region"].values[0]
            if region in imap:
                imap[region].append(row["NameInAssembly"])
            else:
                imap[region] = [row["NameInAssembly"]]

# %% [markdown]
# ### PCA analysis: Mexico and Central America

# %%
select = ["central", "mex_w", "mex_e", "11th_area", "jamaica", "costa"]
imap_central_america = {k: imap[k] for k in select}

# %%
tool = ipa.pca(
    data=DATA,
    imap=imap_central_america,
    minmap=0.5,
    mincov=0.75,
    minmaf=0.02,
    random_seed=123,
    cores=20,
)
# Out:
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:10 | SNP filtering        | ipa |
# ipa | snps_extracter.py | filter statistics:
# samples                                          116
# pre_filter_snps                              3419673
# pre_filter_percent_missing                        67
# filter_by_indels_present                           0
# filter_by_non_biallelic                       129070
# filter_by_mincov                             3392855
# filter_by_minmap                             3153237
# filter_by_invariant_after_subsampling        1611534
# filter_by_minor_allele_frequency             2146978
# post_filter_snps                                2931
# post_filter_snp_containing_linkage_blocks        823
# post_filter_percent_missing                       21
# dtype: int64
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 74.6%, 16.6%, 8.8%

# %%
tool.run(50, random_seed=333, subsample=True)
# Out:
# ipa | snps_extracter.py | subsampled 823 unlinked SNPs.

# %%
tool.draw(
    colors=[region_colors[i] for i in imap_central_america],
    centroids_only=True,
    size=8,
    #outfile="./figures/Oreinotinus-CA.svg",
);
# Out:
# <div class="toyplot" id="tcb0a25e80036484e91a5bde0cc0876cc" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t0e64e77112644e7390c60851afa9619a"><g class="toyplot-coordinates-Cartesian" id="t5446014a2d354bf09e5fc6b31e4fc39b"><clipPath id="t86da826b67154a2c82fd197afb7869d0"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#t86da826b67154a2c82fd197afb7869d0)"><g class="toyplot-mark-Point" id="t37bae341cd7043a58658da0649008fb2"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(80.50221105786457, 181.53097723024436)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(77.32941194615283, 176.53349360277102)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(103.43311020310841, 155.83602763251565)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(104.69667155549092, 170.18186356949465)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(100.73152584770037, 160.85714321570498)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(168.3415642817469, 72.44768787765943)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(168.21312857701582, 65.40560397535593)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(171.77920351873013, 66.21114920139006)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(170.65686800095318, 77.74958769315631)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(163.73498398492055, 71.19632273346248)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(167.0981493072937, 72.66824024709467)"><title>ac ...

# %%
tool.run_umap(n_neighbors=5, random_seed=333, subsample=True, min_dist=0.8)
# Out:
# ipa | snps_extracter.py | subsampled 823 unlinked SNPs.

# %%
tool.draw(
    colors=[region_colors[i] for i in imap_central_america],
    centroids_only=True,
    size=8,
    #outfile="./figures/Oreinotinus-CA-umap.svg",
);
# Out:
# <div class="toyplot" id="t093b7641404d43d8813d75866361c42c" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t19da4892ff6545a088938af72b093752"><g class="toyplot-coordinates-Cartesian" id="td01e0de127bc43a8906a5dbe57e60274"><clipPath id="t2985bb73fadc49d996d6a410765893ec"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#t2985bb73fadc49d996d6a410765893ec)"><g class="toyplot-mark-Point" id="ta35b7f4a62614c48afa1ad5d5d8301c2"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(208.62591734668, 203.4437047115995)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(213.34882282261214, 192.1119811156436)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(208.84593706461322, 209.85736254723457)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(215.36778927453665, 198.24443473822618)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(224.1829786949346, 191.93110318092045)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(98.33756231492873, 224.12207619837974)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(93.4495587365212, 220.76230658901656)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(77.68382605046959, 239.72784547815579)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(83.59863207346771, 240.0)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(86.79747913078336, 227.26356834795212)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(80.28034804896996, 218.63264697390218)"><title>acutifolium_PWS_30 ...

# %% [markdown]
# ### PCA Analysis: South America

# %%
select = ["col_w", "bol", "peru", "col_e", "ecu_n"]
imap_south_america = {k: imap[k] for k in select}

# %%
tool = ipa.pca(
    data=DATA,
    imap=imap_south_america,
    minmap=0.5,
    mincov=0.75,
    minmaf=0.02,
    random_seed=123,
    cores=20,
)
# Out:
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:06 | SNP filtering        | ipa |
# ipa | snps_extracter.py | filter statistics:
# samples                                           62
# pre_filter_snps                              3419673
# pre_filter_percent_missing                        57
# filter_by_indels_present                           0
# filter_by_non_biallelic                        72203
# filter_by_mincov                             3083036
# filter_by_minmap                             2670397
# filter_by_invariant_after_subsampling        2381817
# filter_by_minor_allele_frequency             2463579
# post_filter_snps                               37737
# post_filter_snp_containing_linkage_blocks      11006
# post_filter_percent_missing                       19
# dtype: int64
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 62.8%, 24.2%, 12.9%

# %%
tool.run(50, random_seed=333, subsample=True)
# Out:
# ipa | snps_extracter.py | subsampled 11006 unlinked SNPs.

# %%
tool.draw(
    colors=[region_colors[i] for i in imap_south_america],
    centroids_only=True,
    size=8,
    #outfile="./figures/Oreinotinus-SA.svg",
);
# Out:
# <div class="toyplot" id="td95d820c100f4e568c56dd03b9307634" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t2dcd46c205674d8199e14d8f2260a2e5"><g class="toyplot-coordinates-Cartesian" id="t2deca703e4484b7faf3112c0ecf5dc76"><clipPath id="t1b0c0bcbc9a34420b7574fc789babbbf"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#t1b0c0bcbc9a34420b7574fc789babbbf)"><g class="toyplot-mark-Point" id="ta18581d54e964fe991a8893e5f3ec75c"><g class="toyplot-Series"><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(71.647938013774, 202.90327366475245)"><title>anabaptista_PWS_2156</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(69.02827524045777, 226.71178063941127)"><title>anabaptista_PWS_2160</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(61.99831526173923, 222.15236500389545)"><title>anabaptista_PWS_2162</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(60.960937140692394, 240.0)"><title>anabaptista_PWS_2164</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(66.86658951117539, 222.81957764818256)"><title>anabaptista_PWS_2165</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(71.5183015953967, 216.30214722334432)"><title>anabaptista_PWS_2173</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(234.81060714634458, 171.04257881758497)"><title>ayavacense_PWS_3884</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(224.24637170356164, 171.75585477481778)"><title>ayavacense_PWS_3889</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(240.0, 176.148135677627)"><title>ayavacense_PWS_3902</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(231.7233435696533, 175.42460391674268)"><title>ayavacense_PWS_3908</title><circle r="4.0"></circle></g><g style="fill:rgb(100%,40%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(156.02015117647983, 161.46734946066374)"><title>ayavacense_PWS_4000</title><circle r="4.0"></circ ...

# %%
tool.run_umap(n_neighbors=3, random_seed=333, subsample=True, min_dist=0.15)
tool.draw(
    colors=[region_colors[i] for i in imap_south_america],
    centroids_only=True,
    size=8,
    #outfile="./figures/Oreinotinus-SA.svg",
);
# Out:
# ipa | snps_extracter.py | subsampled 11006 unlinked SNPs.
# <div class="toyplot" id="tee322d83b87249769eecdec7be8e68c0" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t816ee3d63a0b41f080c56a23dedc572a"><g class="toyplot-coordinates-Cartesian" id="t49dca3bfca414fb4a3856fde7498d630"><clipPath id="t799dec12dbda450bb6cfe8af7f04b84c"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#t799dec12dbda450bb6cfe8af7f04b84c)"><g class="toyplot-mark-Point" id="t464873476cc04ebaa35e41faa5740819"><g class="toyplot-Series"><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(238.03483520210483, 75.16266146507903)"><title>anabaptista_PWS_2156</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(224.1896971125682, 66.73287819441353)"><title>anabaptista_PWS_2160</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(227.83125944234902, 73.38937584084145)"><title>anabaptista_PWS_2162</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(219.22144139063317, 100.29093349473308)"><title>anabaptista_PWS_2164</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(234.06057459584176, 95.63297446977988)"><title>anabaptista_PWS_2165</title><circle r="4.0"></circle></g><g style="fill:rgb(40%,100%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(224.16147123359474, 66.81102744945542)"><title>anabaptista_PWS_2173</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(90.1256025117933, 129.39037309056468)"><title>ayavacense_PWS_3884</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(84.47633182084459, 156.6009025423596)"><title>ayavacense_PWS_3889</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(77.35798578637423, 160.6916303151372)"><title>ayavacense_PWS_3902</title><circle r="4.0"></circle></g><g style="fill:rgb(83.1%,100%,16.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(72.4406898438865, 189.1226193798863)"><title>ayavacense_PWS_3908</title><circle r="4.0"></circle></g><g style="fill:rgb(100%,40%,0%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(65.88386488833619, 174.5805090991197)"><title>ayavacense_PWS_4000</title><c ...

# %% [markdown]
# ### PCA Analysis: Full sampling

# %%
tool = ipa.pca(
    data=DATA,
    imap=imap,
    minmap=1,
    mincov=0.75,
    minmaf=0.02,
    random_seed=123,
    cores=20,
)
# Out:
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:15 | SNP filtering        | ipa |
# ipa | snps_extracter.py | filter statistics:
# samples                                          178
# pre_filter_snps                              3419673
# pre_filter_percent_missing                        63
# filter_by_indels_present                           0
# filter_by_non_biallelic                       193270
# filter_by_mincov                             3357698
# filter_by_minmap                             2552916
# filter_by_invariant_after_subsampling         908359
# filter_by_minor_allele_frequency             2130075
# post_filter_snps                                5714
# post_filter_snp_containing_linkage_blocks       1917
# post_filter_percent_missing                       21
# dtype: int64
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 73.0%, 17.2%, 9.7%

# %%
tool.run(50, random_seed=333, subsample=True)
# Out:
# ipa | snps_extracter.py | subsampled 1917 unlinked SNPs.

# %%
tool.draw(
    colors=[region_colors[i] for i in imap],
    centroids_only=True,
    size=8, 
    cycle=11,
    #outfile="./figures/Oreinotinus-full.svg",
);
# Out:
# <div class="toyplot" id="tbe6a65cb405b47d8a162c398a476c4c6" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="ta8cf3e4d9e7749e99e5926ded524cccf"><g class="toyplot-coordinates-Cartesian" id="t748b6242e15348309befe57d6a1c6485"><clipPath id="t02cbf56ecc4a44b5b3ccb16b99d2e50d"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#t02cbf56ecc4a44b5b3ccb16b99d2e50d)"><g class="toyplot-mark-Point" id="t474d8bab0c484782bf1779bbb9d08c7d"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(123.98704673260056, 224.99158291977028)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(130.35046986837693, 220.81771560195762)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(119.31290821874023, 210.35840472446552)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(125.61751978966818, 215.9024248736312)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(118.34494107093761, 218.7236176526381)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(100.23875540895727, 209.1350937900927)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(100.57285493898321, 206.56218185110922)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(98.94261037607232, 203.14709525228812)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(103.81385157108033, 203.4018902630621)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(100.8910138590726, 207.07351618681045)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(101.80188869736048, 207.67180215060253)"><titl ...

# %% [markdown]
# #### Full analysis using UMAP

# %%
tool.run_umap(n_neighbors=55, random_seed=333, subsample=True)
tool.draw(
    colors=[region_colors[i] for i in imap],
    centroids_only=True,
    size=8, 
    cycle=11,
    #outfile="./figures/Oreinotinus-full-umap.svg",
);
# Out:
# ipa | snps_extracter.py | subsampled 1917 unlinked SNPs.
# <div class="toyplot" id="t65485694bce24dc5bc621eb2eb1c4d82" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t923ec94b6fcb4402844e867a83e542e1"><g class="toyplot-coordinates-Cartesian" id="tbbd4fb1df14f4164ba686cd8170dee72"><clipPath id="tb3fc60e45c7c48e683ba9f8cf5b12d9f"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#tb3fc60e45c7c48e683ba9f8cf5b12d9f)"><g class="toyplot-mark-Point" id="t68f8bf3634db4e2db2cc8ddf5ed0f704"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(99.08101549938645, 120.19644249183432)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(124.5605522250223, 114.58537224609975)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(116.62235575094252, 115.4787185405429)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(125.3133366652822, 93.65274275952439)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(121.389981438885, 118.81663197557843)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(60.38968513083238, 82.40082292119018)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(60.0, 74.76895280416971)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(74.49318764490064, 60.92868581718334)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(65.35213154330265, 68.64054742148738)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(66.39773131411894, 90.7937207914287)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(64.62569267467524, 80.5720708424017)"><title>acutifolium_PWS_3050</titl ...

# %% [markdown]
# #### Full analysis using t-SNE

# %%
tool.run_tsne(perplexity=20, random_seed=333, subsample=True)
tool.draw(
    colors=[region_colors[i] for i in imap],
    centroids_only=True,
    size=8, 
    cycle=11,
    #outfile="./figures/Oreinotinus-full-tsne.svg",
);
# Out:
# ipa | snps_extracter.py | subsampled 1917 unlinked SNPs.
# <div class="toyplot" id="t73e91059d26a41608aff2c38e78bfb78" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tee5f7cadb7a04f53bf54ac9aa5696b70"><g class="toyplot-coordinates-Cartesian" id="te98019a4ec304530830fb1f4e77cacb0"><clipPath id="t32f6dbc05e334a35a3481c5e84145dd0"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#t32f6dbc05e334a35a3481c5e84145dd0)"><g class="toyplot-mark-Point" id="t4bd80b3a248b45739a8bb40e3cb145d9"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(137.9517700742606, 153.81991114275465)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(149.20704183894688, 158.39596419732118)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(113.78210859007412, 164.66876994485625)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(140.8529896729133, 142.95104559110905)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(118.61744317778172, 171.28899570910622)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(106.73994143361944, 222.01254295970145)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(104.19259370529812, 227.56849781974375)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(98.74838529995819, 214.33727076206955)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(93.96320383551762, 219.46851802849014)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(107.10537433587166, 215.99549992796403)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(101.44731803657679, 221.74654654441719)"><ti ...

# %% [markdown]
# ### Kmeans approach: imputation without a-priori assignments
# This analysis is used to validate that the a-priori IMAP assignments of samples to populations does not significantly affect the results. Here the input IMAP is used only to select which samples are included in the analysis. Then, SNPs are sampled allowing very little missing data (mincov=0.9), a PCA is performed, and samples are assigned to populations by grouping into KMeans groups. This new imap grouping is then used for the next iteration to impute data by populatiosn with a lower missing threshold, and continues over iterations until we reach the target mincov (0.85 here).

# %%
tool = ipa.pca(
    data=DATA,
    imap=imap,
    minmap=1,
    mincov=0.75,
    minmaf=0.02,
    random_seed=123,
    cores=20,
    kmeans_mincov_max=0.9,
    kmeans_niters=5,
    kmeans_clusters=4,
)
# Out:
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:15 | SNP filtering        | ipa |
# ipa | snps_extracter.py | filter statistics:
# samples                                          178
# pre_filter_snps                              3419673
# pre_filter_percent_missing                        63
# filter_by_indels_present                           0
# filter_by_non_biallelic                       193270
# filter_by_mincov                             3417640
# filter_by_minmap                               23522
# filter_by_invariant_after_subsampling         908359
# filter_by_minor_allele_frequency                   0
# post_filter_snps                                1271
# post_filter_snp_containing_linkage_blocks        202
# post_filter_percent_missing                        5
# dtype: int64
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 90.3%, 2.1%, 7.6%
# ipa | snps_extracter.py | subsampled 202 unlinked SNPs.
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:15 | SNP filtering        | ipa |
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 93.7%, 2.3%, 3.9%
# ipa | snps_extracter.py | subsampled 347 unlinked SNPs.
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:15 | SNP filtering        | ipa |
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 95.1%, 2.8%, 2.2%
# ipa | snps_extracter.py | subsampled 918 unlinked SNPs.
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:15 | SNP filtering        | ipa |
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 94.7%, 3.4%, 1.8%
# ipa | snps_extracter.py | subsampled 2052 unlinked SNPs.
# Establishing parallel cluster (20 cores)
# [####################] 100% 0:00:15 | SNP filtering        | ipa |
# ipa | snps_extracter.py | filter statistics:
# samples                                          178
# pre_filter_snps                              3419673
# pre_filter_percent_missing                        63
# filter_by_indels_present                           0
# filter_by_non_biallelic                       193270
# filter_by_mincov                             3357698
# filter_by_minmap                              810648
# filter_by_invariant_after_subsampling         908359
# filter_by_minor_allele_frequency                   0
# post_filter_snps                               41084
# post_filter_snp_containing_linkage_blocks       4721
# post_filter_percent_missing                       21
# dtype: int64
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ipa | snps_imputer.py | Imputation: sampled genotypes (0, 1, 2) = 94.1%, 3.9%, 1.9%

# %%
tool.run(nreplicates=1, random_seed=123)
tool.draw(
    colors=[region_colors[i] for i in imap],
    #centroids_only=True,
    size=8, 
    cycle=11,
);
# Out:
# ipa | snps_extracter.py | subsampled 4721 unlinked SNPs.
# <div class="toyplot" id="t13cf45659114456e81d042a9d67e2de5" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tb78dff8a6ec641eda6df468ca96a04ea"><g class="toyplot-coordinates-Cartesian" id="t3653873c5c084ef19121998021d5145f"><clipPath id="tab238c347c41440391b9c0dcddfca615"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#tab238c347c41440391b9c0dcddfca615)"><g class="toyplot-mark-Point" id="taa4a872203e745b49a7a9bb228fc583b"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(161.32519132704465, 219.59902960117628)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(140.12351816435097, 200.47832356827303)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(166.60598211696737, 187.38386651887512)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(176.6999537729805, 203.37746086402703)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(224.19506390575538, 82.7163845617145)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(171.11594380943214, 203.7526352902575)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(176.49372938692736, 208.4279749004747)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(175.96316030275563, 180.24608244015735)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(171.21594408875453, 216.75527095312543)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(175.415006203845, 203.62742867589654)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(176.55362762977163, 212.58583776824221)"><title ...

# %%
tool.run_umap(n_neighbors=85, random_seed=333, subsample=True)
tool.draw(
    colors=[region_colors[i] for i in imap],
    centroids_only=True,
    size=8, 
    cycle=11,
);
# Out:
# ipa | snps_extracter.py | subsampled 4721 unlinked SNPs.
# <div class="toyplot" id="ta110e5b2c8fb45f09463fe3ea84703d5" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t530b893534644262a721ae76ccdb496f"><g class="toyplot-coordinates-Cartesian" id="td24b57dac1ce40a8863bf0690c4c27f4"><clipPath id="tbc8997dcde47427e9f1bddfaf0001c5a"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#tbc8997dcde47427e9f1bddfaf0001c5a)"><g class="toyplot-mark-Point" id="t95bf4908025a4931add7b039a33b03cf"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(204.42646243403715, 178.3241316113859)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(210.45134478417918, 177.59224761465532)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(226.28610788513947, 95.93392145476145)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(210.47841746034698, 73.00273938864186)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(112.42923634489658, 116.18338812513053)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(205.64547232770582, 60.0)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(194.16904035670566, 63.491398512834316)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(204.32404637685, 72.53395260338507)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(190.71914335132664, 68.03601891614863)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(217.8300663499667, 94.11701499600984)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(185.9620345771161, 76.71427898783875)"><title>acutifolium_PWS_30 ...

# %%
tool.run_tsne(perplexity=20, random_seed=333, subsample=True)
tool.draw(
    colors=[region_colors[i] for i in imap],
    centroids_only=True,
    size=8, 
    cycle=11,
);
# Out:
# ipa | snps_extracter.py | subsampled 4721 unlinked SNPs.
# <div class="toyplot" id="t25b07c5133cb47b59cc4ae0f61e31af3" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="td3f8009dec6e431382db2d0a6d56ea2f"><g class="toyplot-coordinates-Cartesian" id="tcecd7fd2e0ec4652a86ba322a19da04c"><clipPath id="tefe07b31adca42849e15e7b439a084fa"><rect x="40.0" y="40.0" width="220.0" height="220.0"></rect></clipPath><g clip-path="url(#tefe07b31adca42849e15e7b439a084fa)"><g class="toyplot-mark-Point" id="t6b7386f8c3f943e6835702667c8e946b"><g class="toyplot-Series"><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(145.03996167759124, 240.0)"><title>__EJE_617</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(153.92709948382674, 236.84213179565626)"><title>__EJE_619</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(218.41726494296566, 163.59579851427287)"><title>__EJE_629</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(212.30794802796396, 191.02494783148018)"><title>__EJE_630</title><circle r="4.0"></circle></g><g style="fill:rgb(82.7%,37.3%,37.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(93.40170236556895, 196.34810558765838)"><title>__EJE_631</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(221.01104459719681, 197.99901391567897)"><title>acutifolium_DRY3_MEX_006</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(204.51846624223887, 193.08075414445668)"><title>acutifolium_MEX_005</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(228.59862836456347, 206.42595991094944)"><title>acutifolium_MJD_011_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(223.2010074633783, 176.51782863621457)"><title>acutifolium_MJD_012_tuton_111816</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(211.4544498558797, 198.5254233059107)"><title>acutifolium_MJD_60</title><circle r="4.0"></circle></g><g style="fill:rgb(52.9%,80.4%,87.1%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(207.69179742235244, 204.06696131229415)"><title>acutifoli ...
